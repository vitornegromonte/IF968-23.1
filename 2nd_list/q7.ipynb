# %%
score = 0
stop = False
n = 0
# Pontuação do elo
## Bronze: 1 pt
## Prata: 2 pts
## Ouro: 4 pts
## Platina: 6 pts   
## Diamante:8 pts
## Desafiante: 10 pts

nomeJogador1 = str(input())
laneJogador1 = str(input())
eloJogador1 = str(input())

nomeJogador2 = str(input())
laneJogador2 = str(input())
eloJogador2 = str(input())

nomeJogador3 = str(input())
laneJogador3 = str(input())
eloJogador3 = str(input())

nomeJogador4 = str(input())
laneJogador4 = str(input()) 
eloJogador4 = str(input())

nomeJogador5 = str(input())
laneJogador5 = str(input())
eloJogador5 = str(input())

pontosMax = 18
stop = False

while stop == False:
    # Testando 
    if (nomeJogador1 =='Bruna') | (nomeJogador2 =='Bruna') | (nomeJogador3 =='Bruna') | (nomeJogador4 =='Bruna') | (nomeJogador5 =='Bruna'):
        print("LOL NÃO!!! TUDO MENOS LOL!!!")
        stop = True
    elif eloJogador1 != 'Bronze' or eloJogador1 != 'Prata' or eloJogador1 != 'Ouro' or eloJogador1 != 'Platina' or eloJogador1 != 'Diamante' or eloJogador1 != 'Desafiante' or eloJogador2 != 'Bronze' or eloJogador2 != 'Prata' or eloJogador2 != 'Ouro' or eloJogador2 != 'Platina' or eloJogador2 != 'Diamante' or eloJogador2 != 'Desafiante' or eloJogador3 != 'Bronze' or eloJogador3 != 'Prata' or eloJogador3 != 'Ouro' or eloJogador3 != 'Platina' or eloJogador3 != 'Diamante' or eloJogador3 != 'Desafiante'
    
# nome e elo
# validar nome
# verificar nome igual primeiro if (arthur, frej, amboa) -> fatora

# %%
# Pontuações dos elos
pontuacao_bronze = 1
pontuacao_prata = 2
pontuacao_ouro = 4
pontuacao_platina = 6
pontuacao_diamante = 8
pontuacao_desafiante = 10

# Controlar o time
time_com_artur = False
time_com_frej = False
time_completo = False
dentro = False
# Contadores
pontuacao_total = 0
pontuacao_minima_vitoria = 18

# Guardando os jogadores
jogador_top = None
jogador_jungler = None
jogador_mid = None
jogador_adc = None
jogador_suporte = None

# Armazenar a ordem de entrada dos jogadores
ordem_jogadores = []

while not time_completo:
    nome = input()

    if nome == 'Bruna':
        print("LOL NÃO!!! TUDO MENOS LOL!!!")
        break

    lane = input()
    elo = input()

    if nome == 'Artur':
        time_com_artur = True
        pontuacao_total -= 10
        print("Ele tá meio enferrujado...")
        
    elif nome == 'Frej':
        time_com_frej = True
        pontuacao_total += 10
        print("Joga muito!")

    if lane == 'Top':
        if jogador_top is None:
            jogador_top = f"{nome} - {lane} ({elo})"
            ordem_jogadores.append(jogador_top)
            print(f"{nome} entrou pro time.")
            dentro = True
            
        else:
            print(f"{nome} não foi aceito, que pena.")
            dentro = False
            
    elif lane == 'Jungler':
        if jogador_jungler is None:
            jogador_jungler = f"{nome} - {lane} ({elo})"
            ordem_jogadores.append(jogador_jungler)
            print(f"{nome} entrou pro time.")
            dentro = True
            
        else:
            print(f"{nome} não foi aceito, que pena.")
            dentro = False
            
    elif lane == 'Mid':
        if jogador_mid is None:
            jogador_mid = f"{nome} - {lane} ({elo})"
            ordem_jogadores.append(jogador_mid)
            print(f"{nome} entrou pro time.")
            dentro = True
            
        else:
            print(f"{nome} não foi aceito, que pena.")
            dentro = False
            
    elif lane == 'Adc':
        if jogador_adc is None:
            jogador_adc = f"{nome} - {lane} ({elo})"
            ordem_jogadores.append(jogador_adc)
            print(f"{nome} entrou pro time.")
            dentro = True
        else:
            print(f"{nome} não foi aceito, que pena.")
            dentro = False
            
    elif lane == 'Suporte':
        if jogador_suporte is None:
            jogador_suporte = f"{nome} - {lane} ({elo})"
            ordem_jogadores.append(jogador_suporte)
            print(f"{nome} entrou pro time.")
            dentro = True
            
        else:
            print(f"{nome} não foi aceito, que pena.")
            dentro = False
    
    if dentro == True:
        if elo == 'Bronze':
            pontuacao_total += pontuacao_bronze
        elif elo == 'Prata':
            pontuacao_total += pontuacao_prata
        elif elo == 'Ouro':
            pontuacao_total += pontuacao_ouro
        elif elo == 'Platina':
            pontuacao_total += pontuacao_platina
        elif elo == 'Diamante':
            pontuacao_total += pontuacao_diamante
        elif elo == 'Desafiante':
            pontuacao_total += pontuacao_desafiante
        else:
            print("Não conheço esse elo, então vou considerar que é um elo ruim.")
                
    if (
        jogador_top is not None and
        jogador_jungler is not None and
        jogador_mid is not None and
        jogador_adc is not None and
        jogador_suporte is not None
        ):
        time_completo = True
        print("O time está completo.")
    
if time_completo == True:
    # Imprimir a ordem de entrada dos jogadores
    for jogador in ordem_jogadores:
        print(jogador)
    
    
    if time_com_artur == True and time_com_frej == False:
        print('Vai dar ruim...')
        
    elif time_com_artur == False and time_com_frej == True:
        print("A GENTE VAI GANHAR!!!")
        
    elif time_com_artur == True and time_com_frej == True:
        if pontuacao_total > pontuacao_minima_vitoria:
            print("A GENTE VAI GANHAR!!!")
        elif pontuacao_total < pontuacao_minima_vitoria:
            print("Vai dar ruim...")
    else:
        if pontuacao_total > pontuacao_minima_vitoria:
            print("A GENTE VAI GANHAR!!!")
        elif pontuacao_total < pontuacao_minima_vitoria:
            print("Vai dar ruim...")
# Out:
# Sergio entrou pro time.
# Nivan entrou pro time.
# Calegario entrou pro time.
# Silvio não foi aceito, que pena.
# Anjolina entrou pro time.
# Gustavo não foi aceito, que pena.
# Ricardo entrou pro time.
# O time está completo.
# Sergio - Top (Bronze)
# Nivan - Jungler (Ouro)
# Calegario - Mid (Bronze)
# Anjolina - Adc (Diamante)
# Ricardo - Suporte (Bronze)
# Vai dar ruim...
