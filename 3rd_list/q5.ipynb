# %%
# Contadores
## Parada
stop = False

# Recebendo os valores de cada seção e transformando listas
itens_penteados = input().split(' - ')
itens_tops = input().split(' - ')
itens_bottoms = input().split(' - ')
itens_sapatos = input().split(' - ')

# Definindo a posição central de cada seção e arredondando o valor
pos_penteado = len(itens_penteados)
pos_tops = len(itens_tops)/2
pos_bottom = len(itens_bottoms)/2
pos_sapatos = len(itens_sapatos)/2

dec_penteados = int(pos_penteado)
dec_tops = int(pos_tops)
dec_bottom = int(pos_bottom)
dec_sapatos = int(pos_sapatos)


# Recebendo os movimentos da máquina
actions = input().split()

# Imprimindo mensagem inicial
print('Triagem das peças realizada com sucesso, pronta para iniciar mesclagem!')

while not stop:
        
        # Imprimindo mensagem de início da máquina
        print("Iniciando mesclagem...")

        movimentos = input().split() # Lista de movimentos

        for i in range(len(movimentos[0][-1])): ## Percorrendo a lista de penteados[0]
                if movimentos[0][-1] == '>':
                        pos_penteado += 1 % len(itens_penteados)
                        
                else:
                        pos_penteado -= 1 % len(itens_penteados)
                        
                esc_penteados = itens_penteados[pos_penteado]
                                                
        for a in range(len(movimentos[1][-1])): ## Percorrendo a lista de tops[1]
                if movimentos[1][-1] == '>':
                        pos_tops += 1 % len(itens_tops)
                else:
                        pos_tops -= 1 % len(itens_tops)
                        
                esc_tops = itens_tops[pos_tops]
                
        for y in range(len(movimentos[2][-1])): ## Percorrendo a lista de bottoms[2]
                if movimentos[2][-1] == '>':
                        pos_bottom += 1 % len(itens_bottoms)
                else:
                        pos_bottom -= 1 % len(itens_bottoms)
                        
                esc_bottom = itens_bottoms[pos_bottom]
                
        for x in range(len(movimentos[3][-1])): ## Percorrendo a lista de sapatos[3]
                if movimentos[3][-1] == '>':
                        pos_sapatos += 1 % len(itens_sapatos)
                else:
                        pos_sapatos -= 1 % len(itens_sapatos)
                        
                esc_sapatos = itens_sapatos[pos_sapatos]
                
                
        print(f'O look gerado foi:\ncabelo {esc_penteados}, {esc_tops} com {esc_tops} e {esc_sapatos} nos pés.')
        
        opinion = input()
        
        if opinion == 'Amei!':
                if esc_tops == 'camisa da seleção':
                        print('Essa Barbie vai torcer pela seleção feminina na copa do mundo 2023!')
                else:
                        print('Essa Barbie vai arrasar com o look perfeito!')
                stop = True

        elif opinion == 'Melhor escolher eu mesma':
                print('Acho que estou precisando de ajustes, Ken :(')
                stop = True
                
        elif opinion == 'Acho que não combinou muito :/':
                stop = False
