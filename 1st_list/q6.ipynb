# %%
# Aranha
nomeAranha = input()
ataqueAranha = int(input())
defesaAranha = int(input())

# Aliado
nomeAliado = input()
ataqueAliado = int(input())
defesaAliado = int(input())

# Vilão
nomeVilao = input()
ataqueVilao = int(input())
defesaVilao = int(input())

# Capanga
nomeCapanga = input()
ataqueCapanga = int(input())
defesaCapanga = int(input())

vitorias = 0 
derrotas = 0

# Fator de sorte
fator_sorte = int(input())

if fator_sorte == 0:
    # Ambos atavam e defendem sozinhos: Aranha vence em caso de empate
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao
elif fator_sorte == 1:
    # Dano = Atacante + parceiro: Em caso de empate, vence quem tiver capanga ou aliado
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao
elif fator_sorte == 2:
    # Defesa = Defensor + parceiro: Em caso de empate, vence quem tiver capanga ou aliado
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao + defesaCapanga
elif fator_sorte == 3:
    # Ataque e defesa em dupla: Em caso de empate, Aranha vence
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao + defesaCapanga
    
    
# Confronto:
# 1ª rodada = ARANHA ATACA
print('1° confronto:')
if rodada_danoAranha > rodada_defVilao:
    print(f'O {nomeAranha} acertou vários golpes no {nomeVilao}')
    vitorias += 1
    
elif rodada_danoAranha == rodada_defVilao:
    if fator_sorte == 0 or fator_sorte == 1 or fator_sorte == 3:
        # Aranha wins
        print(f'O {nomeAranha} acertou vários golpes no {nomeVilao}')
        vitorias += 1
        
    elif fator_sorte == 2:
        print(f'O {nomeVilao} está dificultando a vida do {nomeAranha}')
        derrotas += 1
else:
    print(f'O {nomeVilao} está dificultando a vida do {nomeAranha}')
    derrotas += 1
    
    
# 2ª rodada: VILÃO ATACA
print('2° confronto:')
fator_sorte = int(input())

if fator_sorte == 0:
    # Ambos atavam e defendem sozinhos:
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao
elif fator_sorte == 1:
    # Dano = Atacante + parceiro
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao
elif fator_sorte == 2:
    # Defesa = Defensor + parceiro
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao + defesaCapanga
elif fator_sorte == 3:
    # Ataque e defesa em dupla
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao + defesaCapanga

if rodada_danoVilao > rodada_defAranha:
    print(f'O {nomeAranha} não consegue se defender contra o {nomeVilao}')
    derrotas += 1
elif rodada_danoVilao == rodada_defAranha:
    if fator_sorte == 1:
        # Aranha loses
        print(f'O {nomeAranha} não consegue se defender contra o {nomeVilao}')
        derrotas += 1
    elif fator_sorte == 0 or fator_sorte == 2 or fator_sorte == 3:
        # Aranha wins
        print(f'O {nomeAranha} contra-atacou o {nomeVilao}')
        vitorias += 1
else:
    print(f'O {nomeAranha} contra-atacou o {nomeVilao}')
    vitorias += 1

# 3ª rodada: ARANHA ATACA
print('3° confronto:')
fator_sorte = int(input())

if fator_sorte == 0:
    # Ambos atavam e defendem sozinhos:
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao
elif fator_sorte == 1:
    # Dano = Atacante + parceiro
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao
elif fator_sorte == 2:
    # Defesa = Defensor + parceiro
    rodada_danoAranha = ataqueAranha
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao
    rodada_defVilao = defesaVilao + defesaCapanga
elif fator_sorte == 3:
    # Ataque e defesa em dupla
    rodada_danoAranha = ataqueAranha + ataqueAliado
    rodada_defAranha = defesaAranha + defesaAliado
    rodada_danoVilao = ataqueVilao + ataqueCapanga
    rodada_defVilao = defesaVilao + defesaCapanga
    
if rodada_danoAranha > rodada_defVilao:
    print(f'O {nomeAranha} acertou vários golpes no {nomeVilao}')
    vitorias += 1
    
elif rodada_danoAranha == rodada_defVilao:
    if fator_sorte == 0 or fator_sorte == 1 or fator_sorte == 3:
        # Aranha wins
        print(f'O {nomeAranha} acertou vários golpes no {nomeVilao}')
        vitorias += 1
        
    elif fator_sorte == 2:
        print(f'O {nomeVilao} está dificultando a vida do {nomeAranha}')
        derrotas += 1
else:
    print(f'O {nomeVilao} está dificultando a vida do {nomeAranha}')
    derrotas += 1
    
# Conclusão dos confrontos
if vitorias > derrotas:
    print(f'O {nomeAranha} e {nomeAliado} conseguiram derrotar o {nomeVilao} e recuperar o multiverso!')
else: 
    print(f'O {nomeVilao} e {nomeCapanga} invadiram Nova York, onde estão os outros aranhas??')
# Out:
# 1° confronto:
# O Miles acertou vários golpes no Duende verde
# 2° confronto:
# O Miles contra-atacou o Duende verde
# 3° confronto:
# O Miles acertou vários golpes no Duende verde
# O Miles e Aranha-Noir conseguiram derrotar o Duende verde e recuperar o multiverso!
